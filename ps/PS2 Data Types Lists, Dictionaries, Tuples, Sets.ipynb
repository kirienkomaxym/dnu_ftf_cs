# %%
#$@ UNQ ps2

# %% [markdown]
# ## 1 Gate

# %% [markdown]
# ![gate_task-2.png](attachment:gate_task-2.png)

# %% [markdown]
# На зображенні вище, ви можете побачити логічну схему, до якої треба зробити сімуляцію. На вход гейту `A` подається ниска сигналів, в булевій формі, кількість 'входів' гейту `A` - невідома, `len(A) = [2:inf]`. `A` є гейтом `AND` [AND wiki](https://en.wikipedia.org/wiki/AND_gate), виход з гейту `A` є інвертованим (кружочок наприкінці), тобто якщо результатом роботи `A` до інвертування було `True` - результат роботи всього гейту `A` буде `False`.
#
# На вход гейту `B`, також подається невідома кількість значень. `B` є гейтом `NOT`[NOT wiki](https://en.wikipedia.org/wiki/OR_gate), виход з гейту `B` також інвертований. Результатом роботи як гейту `A`, так і гейту `B` є єдине значення (`True / False`).
#
# Два значення виходу з гейтів `A`, `B` потім подаються на вхід гейту `C`, який є гейтом `AND`, і є неінвертованим, в задачі необхідно знайти результат роботи гейту `C`, в залежності від входів гейтів `A` та `B`.
#
# Майте на увазі, що ця задача вирішується **БЕЗ** циклів, які поки не були пройдені протягуом курсу.
#
# <details>
# <summary>Підказка, нажміть сюди</summary>
# Для вирішення цієї задачи продивіться другу лабу, розділ `list`, функції
# </details>

# %%
# DO NOT EDIT ANYTHING EXCEPT OF GIVEN AREA OF CODE
def gate(inputs_A: list, inputs_B: list) -> bool:
    """'
    inputs_A: list of bool values of unknown length
    inputs_A: list of bool values of unknown length
    """
    ### ENTER YOUR CODE HERE ###
    A_result = None
    A_result_inverted =None
    
    B_result = None
    B_result_inverted = None
    
    C_result = None
    
    ### END OF CODE ###
    
    return C_result

# %%
# here you can do testing
inputs_A = [True, False, False, False]
inputs_B = [False, False, False]
print(gate(inputs_A, inputs_B))

inputs_A = [True, True, False, False]
inputs_B = [False, False, False, False, False]
print(gate(inputs_A, inputs_B))

# %%
# self - test 
inputs_A = [True, True, False, False]
inputs_B = [False, False, False, False, False]
expected_result = True

try:
    result = gate(inputs_A, inputs_B)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %%
inputs_A = [True, False]
inputs_B = [False, False, False, False, False]
print(gate(inputs_A, inputs_B))

# %% [markdown]
# ## 2. Поле

# %% [markdown]
# Вам треба імплементувати функція, яка імітує роботу поля (field), [поле](https://uk.wikipedia.org/wiki/%D0%9F%D0%BE%D0%BB%D0%B5_(%D0%B0%D0%BB%D0%B3%D0%B5%D0%B1%D1%80%D0%B0)
#
# Стаття на вікі майже не пов'язана з задачею, але в майбутніх курсах, зокрема крипографії, ви стикнетесь з такім поняттям.
#
# Для розуміння вашої задачи - поле в данному випадку це унікальні елементи, максимальним значенням з цих унікальних елементів є значення порядка поля.
#
# На вход вашої функції подається два аргументи - `values`, та `field_order`. Вам треба зробити так, щоб значення `values` були унікальними, та не превищували порядок поля, тобто максимальне число в результаті роботи функції має не перевищувати значення `field_order`. Результатом роботи вашої функції є `list` який містить в собі тількі унікальні значення, дозволені порядком поля.
#
# Зверніть увагу, ця задача також виріщується без циклів.
#
# Значення `field_order` завжди знаходиться в `values`, тобто `field_order in values == True`. Також це поле має включати в себе і сам `field_order`
#
# Очікуваним результатом роботи функції з наступними значеннями:
#
# ```
# values = [1, 17, 21, 3, 5, 12, 389, 4, 6]
# order = 5
# field_values = field_maker(values, order)
# print(field_values)
# >>> [1, 3, 4, 5]
# ```
#
# <details>
# <summary>Підказка, нажміть сюди</summary>
# Для вирішення цієї задачі необхідно корстуватися властивостями 'set' та `list` (і методами)
# </details>

# %%
# DO NOT EDIT ANYTHING EXCEPT OF GIVEN AREA OF CODE
def field_maker(values: list, field_order: int):
    """
    values: p0sitive ints, nums inside values may repeat
    field_order: order of the field needed to make
    """
    ### ENTER YOUR CODE HERE ###
    field_uniques = None
    field_uniques_list = None
    
    field_order_index = None
    field_values = None
    
    ### END OF CODE ###
    
    return field_values

# %%
values = [1, 2, 4, 15, 32, 99, 10, 6, 3, 11, 1, 2, 3, 4, 15, 6]
order = 11
field_maker(values, order)

# %%
# self - test 
values = [1, 2, 4, 15, 32, 99, 10, 6, 3, 11, 1, 2, 3, 4, 15, 6]
order = 11
expected_result = [1, 2, 3, 4, 6, 10, 11]

try:
    result = field_maker(values, order)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %% [markdown]
# ## 3. Максимум перетину множин

# %% [markdown]
# Функція, яку ви будете редагувати, отримує на вход 4 листа, треба знайти перетин всіх елементів з кожного з 4 листів, а потім знайти максимальне значення з цього перехрестя.

# %%
def lists_intersection_max(values1: list, values2: list,
                          values3: list, values4: list):
    """
    values1, values2, values3, values4: lists of values (values always intersetcs)
    """
    ### ENTER YOUR CODE HERE ###
    set1, set2, set3, set4 = None
    intersection = None
    max_value = None
    
    ### END OF CODE ###
    return max_value

# %%
val1, val2 = [1, 2, 3], [3, 12, 12, 2, 1, 3, 1, 2, 3]
val3, val4 = [3, 2, 4, 1, 2], [21, 3, 1, 4, 6, 1, 2]
print(lists_intersection_max(val1, val2, val3, val4))

# %%
val1, val2 = [1, 17, 12, 13, 5], [4, 12, 21, 21, 12, 21, 4]
val3, val4 = [3, 2, 1, 4, 17, 12, 1, 3], [1, 4, 12, 21, 12]
expected_result = 12

try:
    result = lists_intersection_max(val1, val2, val3, val4)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %% [markdown]
# ## 4. Стовпчик матриці

# %% [markdown]
# На вхід вашої функції подається `list` який завжди має в середині 3 елементи, які теж являються `list`, наприклад `[[1, 2, 3], [3, 2, 1], [3, 1, 4]]` кількість елементів в середині листів меньше, може бути різна, хоча кількість їх завжди однакова.
#
# Цей ліст також можна уявити як репрезентацію матриці, тобто:
# ```
# [
# [1, 2, 3],
# [3, 2, 1],
# [3, 1, 4]
# ]
# ```
#
# Другим аргументом вашої функції є `n` - який означає 'стопчик' матриці.
# Третім елементом функції є `k`, який є рандомним числом.
#
# Ваша функція має зробити наступне:
# * знайти стовпчик, за індексом `n`, тобто з нашого прикладу стовпчик матриці за індексом `n = 1` є `[2, 2, 1]` (пам'ятайте що індексація починається з `0`
# * знайти мінімум від цього стовпчика
# * порівняти значення мінімума з аргументом `k` (чи k більше за мінімум) і віддати результат цієї перевірки
#
# Кількість стовпчиків матриці - завжди 3, кількість строк в матриці - `[2: inf]`, `k > 0`, `n > 2`
#
# Ця задача також вирішується без циклів.

# %%
def matrix_column(matrix: list, n: int, k: int):
    """
    sentence: str
    """
    ### ENTER YOUR CODE HERE ###
    column = None
    column_min = None

    is_k_bigger = None
    
    ### END OF CODE ###
    return is_k_bigger

# %%
matrix = [[1, 2, 3], [3, 2, 1], [1, 1, 1]]
n = 2
k = 4

matrix_column(matrix, n, k)

# %%
matrix = [[1, 2, 3, 6], [3, 2, 1, 3], [3, 2, 17, 4]]
n = 2
k = 1
expected_result = False

try:
    result = matrix_column(matrix, n, k)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %% [markdown]
# ## 5. Визначник Матриці

# %% [markdown]
# На вхід вашої функції подається строка, ліст з листів, (розглядаємо як матрицю), розмір матриці завжди 3х3, треба знайти детерменант матриці.

# %% [markdown]
# ![determant.png](attachment:determant.png)

# %%
def matrix_determinant(matrix: list):
    """
    matrix: list of lists representing matrix
    """
    ### ENTER YOUR CODE HERE ###
    step1 = None
    step2 = None
    step3 = None
    step4 = None
    step5 =None
    step6 = None
    result = None
    
    
    ### END OF CODE ###
    return result

# %%
import numpy as np
matrix = [[1, 2, 3], [3, 2, 1], [1, 1, 1]]
det = matrix_determinant(matrix)
print(det)
np.linalg.det(matrix)
np.linalg.det(np.array(matrix))

# %%
matrix = [[123, 2, 34], [432, 1, 6], [31, 67, 2]]
det = matrix_determinant(matrix)
print(det)

# %%
matrix = [[123, 2, 34], [432, 1, 6], [31, 67, 2]]
expected_result = 932486

try:
    result = matrix_determinant(matrix)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %% [markdown]
# ## 6. Мінор Елемента Матриці

# %% [markdown]
# В цьому завданні вам буде необхідно знайти мінор матриці. Матриця - яка подається на вход функції завжди має розмір 3х3, окремо від матриці, аргументами до функції є `i` (номер строки) та `j` (номер стовпичка), відповідно до позиції елемента, мінор якого треба знайти. Ваша функція має вивести мінор заданої матриці.

# %% [markdown]
# ![minors.jpg](attachment:minors.jpg)

# %%
def matrix_elem_minor(matrix: list, i: int, j: int):
    """
    matrix: list of lists representing matrix size 3x3
    i: int representing row index
    j: int representing col index
    """
    ### ENTER YOUR CODE HERE ###
    rows_indexes = None
    cols_indexes = None
    
    rest_rows_indexes = None
    rest_cols_indexes = None
    
    first_row = None
    second_row = None
    
    Mij = None
    
    det = None
    ### END OF CODE ###
    return det

# %%
matrix = [[2, 3, -1], [1, 4, 2], [-3, 1, 4]]
matrix_elem_minor(matrix, 2, 1)

# %%
args = [[[2, 3, -3], [2, -3, 1], [-6, 7, 4]], 2, 1]
matrix_elem_minor(*args)

# %%
matrix, i, j = [[[2, 3, -3], [2, -3, 1], [-6, 7, 4]], 2, 1]
expected_result = 33

try:
    result = matrix_elem_minor(matrix, i, j)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")

# %% [markdown]
# ## 7. Cловник
#
# Вам надан словник `dicty`, підрахуйте кількість ключів в цьому словнику, та виведить чи є ця кількість ключів парною.
#
# Для рішення цієї задачі не треба користуватись умовами `if`, `else`
#
# Кількість елементів в словнику завжди більше 1.

# %%
def is_dicty_keys_odd(dicty: dict):
    """
    dicty: some dictionary
    """
    ### ENTER YOUR CODE HERE ###
    dicty_keys_amount = None
    is_odd = None
    ### END OF CODE ###
    return is_odd

# %%
dicty = {1: 4, 5:6, 7:7, "A":4}
is_dicty_keys_odd(dicty)

# %%
dicty = {1: 4, 5:6, 7:7, "A":4}
expected_result = True

try:
    result = is_dicty_keys_odd(dicty)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
