# %% [markdown]
# # PS4: Functions

# %%
#$@ UNQ ps4

# %% [markdown]
# ## 1. Геометрична сума

# %% [markdown]
# Напішіть рекурсивну функцію, що рахує геометричну суму числа `n`, тобто:

# %% [markdown]
# ![harmonic-series.png](attachment:harmonic-series.png)

# %% [markdown]
# Якщо `n < 0`, треба повернути 0, якщо `n == 0` - повернути 1

# %%
def geometric_sum(n):
    """
    n: int represeting sum to calculate
    """
    ### ENTER YOUR CODE HERE ###
    res = None
    
    ### END OF CODE ###
    return res

# %%
n = 12
geometric_sum(n)

# %%
# self - test 
n = 12
expected_result = 1.999755859375

try:
    result = geometric_sum(n)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result=1.999755859375, your result result=None

# %% [markdown]
# ## 2. Скарби

# %% [markdown]
# Ви відкрили сейф, в якому лежать скрарби, проте ви не можете забрати їх всі, бо у вас, як у відеогрі є ліміт ваги, яку ви можете нести. Виходячи з цього, вам необхідно забрати тількі ті скарби, які будуть найкоштовніші.
#
# На вход вашої функції подається два аргументи - `info` та `limit`.
# `info` це опис скарбів, який представлений словником зі словниками всередині. Наприклад:
#
# ```
# {
# 'golden coin':
#      {'price': 100, 'weight': 50, 'amount': 200},
#   'silver coin':
#      {'price': 10, 'weight': 20, 'amount': 1000},
#   'ruby':
#      {'price': 1000, 'weight': 200, 'amount': 2}
# }
# ```
# кожен елемент словника це скарб, в якого є відповідні поля - кількість цих скарбів, їх ціна, та вага в **грамах**. В кожному сейфі завжди одні й ті самі назви скарбів - `'golden_coin', 'silver coin', 'ruby'`. Проте ціна, кількість та вага можуть відрізнятися.
#
# `limit` це максимальна вага в **кілограмах**
#
# Вам необхідно, як результат роботи вашої функції, зібрати такий набор скарбів, щоб їх сумарна вага не перевищувала значення `limit`, а їх коштовність була максимальною.
#
# Відповідь необхідно повернути у форматі словника (`dict`), де ключем виступає назва скарбу, а значенням - кількість цього скарбу, який ви взяли із сейфа. Якщо ви не берете якийсь з типів скарбу - його не має бути в словнику.
#
# Приклад відповіді для `info` зазначеного вище, та `limit` зі значенням п'ять наступний:
#
# ```
# {'golden coin': 92, 'ruby': 2}
# ```
#
# Зверніть увагу, що значення кількості вказується в `int`. Порядок значень в ітоговому словнику - неважливий.

# %% [markdown]
# ![treasures.png](attachment:treasures.png)

# %%
def treasures(info: dict, limit: int):
    """
    info: dictionary describing safe items
    limit: int amount of your capability in kg
    """
    ### ENTER YOUR CODE HERE ###
    
    
    
    
    
    res = None
    
    
    
    
    ### END OF CODE ###
    
    return res

# %%
treasures({"golden coin":
    {"price":100,"weight":10,"amount":100},
"silver coin":
    {"price":10,"weight":10,"amount":100},
"ruby":
    {"price":1000,"weight":200,"amount":5}},
    1.8)

# %%
# self - test 
info = {
    "golden coin":
        {"price":100,"weight":10,"amount":100},
    "silver coin":
        {"price":10,"weight":10,"amount":100},
    "ruby":
        {"price":1000,"weight":200,"amount":5}
}
limit = 1.8
expected_result = {'golden coin': 100, 'ruby': 4}

try:
    result = treasures(info, limit)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result={'golden coin': 100, 'ruby': 4}, your result result=None

# %% [markdown]
# ## 3. Ключи та Замки

# %% [markdown]
# В якості вхідних даних ви отримуєте дві багатострокових `str` - одна є схематичним зображенням замочного отвору, інша - ключа. Ваша задача повернути `True`, якщо ключ підходить до замка та `False` якшо ні. Ключ та отвір зображені за допомогою `#`, а пустий простір навколо ключа та отвору - `0`. Майте на увазі, що ключ та отвір можуть бути зображені як вертікально, так і горізонтально
#
# Зверніть увагу, що ключ можна обертати, тобто робити 'розворот' матриці ключа на 90, 180 та 270 градусів.

# %% [markdown]
# ![keyslocks.png](attachment:keyslocks.png)

# %% [markdown]
# В цій задачі, ви на відміну від попередніх, вам необхідно імплементувтаи функції всередині функцій. Кожна функція має виконувати відповідну задачу - підказка до того, яку задачу вона повинна виконувати - назва визначеної функції.

# %%
def keys_and_locks(lock: str, key: str):
    """
    lock: str representing lock matrix
    key: str representing key matrix
    """
    ### ENTER YOUR CODE HERE ###
    def turn90(key):
        ### ENTER YOUR CODE HERE ###
        res = None
        
        ### END OF CODE ###
        return res
    
    def trim(key):
        ### ENTER YOUR CODE HERE ###
        res = None
        
        ### END OF CODE ###
        return res
    
    res = None
    
    ### END OF CODE ###
    return res

# %%
keys_and_locks('''
0##0
0##0
00#0
00##
00##''',
'''
00000
000##
#####
##000
00000''')

# %%
lock = '''0##0\n0##0\n00#0\n00##\n00##'''

key = '''
00000
000##
#####
##000
00000'''

expected_result = True

try:
    result = keys_and_locks(lock, key)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result=True, your result result=None

# %% [markdown]
# ## 4. Статистика

# %% [markdown]
# В цьому завданні на вход вашої функції подається числова послідовність в несортованому вигляді. Ваша задача - вивести базові статистичні значення послідовності - **mean**, **median**, **mode**, та **standard deviation**. Формули для цих статистичних значень можна знайти за [посиланням](https://www.google.com/).
#
# Результатом роботи вашої функції повинен бути словник, де ключем виступає відповідний параметр послідовності, а значенням - значення цього статистичного параметра, тобто:
# ```
# {'mean': 0, 'median': 1, 'mode': 2, 'std': 3}
# ```
#
# Зверність увагу - **standard deviation** скорочено до **std**.
#
# Всі значення мають бути округлені до другого знака, користуючись функцією `round`
#
# Умова - `len(sequence) >= 2`

# %%
def statistics(sequence: list):
    """
    sequence: list of int values
    """
    ### ENTER YOUR CODE HERE ###
    res = None
    ### END OF CODE ###
    return res

# %%
sequence = [1, 5, 3, 1, 6, 1, 3, 5, 7, 12, 144, 2]
statistics(sequence)

# %%
sequence = [1, 5, 3, 1, 6, 1, 3, 5, 7, 12, 144, 2]
expected_result = {'mean': 15.83, 'median': 4.0, 'mode': 1, 'std': 40.49}

try:
    result = statistics(sequence)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result={'mean': 15.83, 'median': 4.0, 'mode': 1, 'std': 40.49}, your result result=None

# %% [markdown]
# ## 5. Транзістор

# %% [markdown]
# ![transistor.png](attachment:transistor.png)

# %% [markdown]
# До вашої уваги схема, яка являє собою підсилювальний каскад, який виконаний на трьох транзісторах. Умовна схема транзистора наступна - якщо на базу `B` подається живлення, то через колектор `C` до емітера `E` подається напруга. Наприклад, якщо `V_in` - має напругу (наприклад - `True`, `5V`, `3.3V`, любу) то на емітері `Q1`, буде напруга, яка дорівнює `V_a`, якщо `V_in` - `False`, або `0`, напруга на емітері - `0V`.
#
# На вход вашої функції подається список `signal` `list`, який імітує сигнал в якийсь момент часу, тобто `[True, False, True, False]` або `[3.3, 0, 3.3, 0, 3.3]`, другим аргументом є кортеж зі значеннями `V_a`, `V_b`, `V_c`, наприклад `(3.3, 5, 12)`. Вам необхідно знайти та вивести значення `V_out` у форматі `float`

# %%
def transistor(signal: list, voltages: tuple):
    """
    signal: list of signals, can be list of bools or list of floats
    voltages: tuple representing voltages v_a, v_b, v_c
    """
    ### ENTER YOUR CODE HERE ###
    res = None
    
    ### END OF CODE ###
    
    return res

# %%
sig = [True, False, False, True, True, False]
voltages = (3.3, 5, 12)
transistor(sig, voltages)

# %%
sig = [True, False, False, True, True, False]
voltages = (3.3, 5, 12)
expected_result = [12, 0, 0, 12, 12, 0]

try:
    result = transistor(sig, voltages)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result=[12, 0, 0, 12, 12, 0], your result result=None

# %% [markdown]
# ## 6. Extension Sort

# %% [markdown]
# Тобі даний список файлів. Потрібно відсортувати його за розширенням файлів. Файли з однаковим розширенням (або без нього) повинні сортуватися за іменем.
#
# Окремі можливі випадки:
#
# * Файл не може бути порожнім рядком;
# * Порядок сортування: файли без імені, файли без розширення, файли з іменем та розширенням;
# * Файли ".config" or "config." це все ім'я з порожнім розширенням;
# * Файли виду "str1.str2.str3" мають розширення "str3" і ім'я "str1.str2";
# * Файли виду ".str1.str2" мають розширення "str2" і ім'я ".str1".

# %%
def sort_by_ext(files: list) -> list:
    
    def key_fn(string):
        ### ENTER YOUR CODE HERE ###
        res = None
        
    
    ### ENTER YOUR CODE HERE ###
    
    res = None
    ### END OF CODE ###

    return res

# %%
files = ['1.cad', '1.bat', '1.aa']
sort_by_ext(files)

# %%
files = ['1.cad', '1.bat', '1.aa']
expected_result = ['1.aa', '1.bat', '1.cad']

try:
    result = sort_by_ext(files)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: None
# Something is wrong with your code expected_result=['1.aa', '1.bat', '1.cad'], your result result=None

# %% [markdown]
# ## 7. Sorting by Absolute

# %% [markdown]
# Вхідний масив містить різні числа. Вам необхідно відсортувати їх, але впорядкувати на основі абсолютних значень у зростаючому порядку. Для прикладу, послідовність `(-20, -5, 10, 15)` буде відсортована таким чином `(-5, 10, 15, -20)`. Ваша функція повинна повертати ліст (`list`).

# %%
def absort(numbers_array: list):
    """
    numbers_array: array of integers or floats
    """
    ### ENTER YOUR CODE HERE ###
    res = None
    ### END OF CODE ###
    return res

# %%
qwe = [-21, -2, -5, -14, 6, 24, -22, 12, 20, -1]
absor
# Out:
# [2, -23, 17, -4, 5, -8, 0, -22, -12, 15, -3, 18, 18, 0, -4, -2, 6]
# None

# %%
numbers_array  = [-21, -2, -5, -14, 6, 24, -22, 12, 20, -1]
expected_result = [-1, -2, -5, 6, 12, -14, 20, -21, -22, 24]

try:
    result = absort(numbers_array)
    print(f"Your result: {result}")
    assert result == expected_result
    print("Self-test passed")
except AssertionError:
    print(f"Something is wrong with your code {expected_result=}, your result {result=}")
# Out:
# Your result: [-1, -2, -5, 6, 12, -14, 20, -21, -22, 24]
# Self-test passed
